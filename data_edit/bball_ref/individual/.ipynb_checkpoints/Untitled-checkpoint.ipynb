# %%
import urllib
from bs4 import BeautifulSoup
import pandas as pd

data = []
data_ = []

for year in range(1950,1953):
    #url = 'https://www.basketball-reference.com/leagues/NBA_'+str(year)+'_totals.html'
    #r = urllib.request.urlopen(url)
    total_url = 'https://www.basketball-reference.com/leagues/NBA_'+str(year)+'_totals.html'
    advanced_url = 'https://www.basketball-reference.com/leagues/NBA_'+str(year)+'_advanced.html'
    r = urllib.request.urlopen(total_url)
    r_ = urllib.request.urlopen(advanced_url)

    total_table = BeautifulSoup(r,'lxml').table
    advanced_table = BeautifulSoup(r_,'lxml').table
    tr = total_table.find_all('tr',class_ = 'full_table')
    tr_ = advanced_table.find_all('tr',class_ = 'full_table')

    for info in tr:
        result = {}
        result['Rk'] = info.find('th',attrs={'data-stat' : 'ranker'}).text
        result['Player'] = info.find('td', class_ = 'left').text
        result['Pos'] = info.find('td', class_ = 'center').text    
        result['Age'] = info.find('td',class_='right').text
        result['Tm'] = info.find('td', attrs={'data-stat' : 'team_id'}).text
        result['G'] = info.find('td', attrs={'data-stat' : 'g'}).text
        result['GS'] = info.find('td', attrs={'data-stat' : 'gs'}).text
        result['MP'] = info.find('td', attrs={'data-stat' : 'mp'}).text
        result['FG'] = info.find('td', attrs={'data-stat' : 'fg'}).text
        result['FGA'] = info.find('td', attrs={'data-stat' : 'fga'}).text
        result['FG%'] = info.find('td', attrs={'data-stat' : 'fg_pct'}).text
        result['3P'] = info.find('td', attrs={'data-stat' : 'fg3'}).text
        result['3PA'] = info.find('td', attrs={'data-stat' : 'fg3a'}).text
        result['3P%'] = info.find('td', attrs={'data-stat' : 'fg3_pct'}).text
        result['2P'] = info.find('td', attrs={'data-stat' : 'fg2'}).text
        result['2PA'] = info.find('td', attrs={'data-stat' : 'fg2a'}).text
        result['2P%'] = info.find('td', attrs={'data-stat' : 'fg2_pct'}).text
        result['eFG%'] = info.find('td', attrs={'data-stat' : 'efg_pct'}).text
        result['FT'] = info.find('td', attrs={'data-stat' : 'ft'}).text
        result['FTA'] = info.find('td', attrs={'data-stat' : 'fta'}).text
        result['FT%'] = info.find('td', attrs={'data-stat' : 'ft_pct'}).text
        result['ORB'] = info.find('td', attrs={'data-stat' : 'orb'}).text
        result['DRB'] = info.find('td', attrs={'data-stat' : 'drb'}).text
        result['TRB'] = info.find('td', attrs={'data-stat' : 'trb'}).text
        result['AST'] = info.find('td', attrs={'data-stat' : 'ast'}).text
        result['STL'] = info.find('td', attrs={'data-stat' : 'stl'}).text
        result['BLK'] = info.find('td', attrs={'data-stat' : 'blk'}).text
        result['TOV'] = info.find('td', attrs={'data-stat' : 'tov'}).text
        result['PF'] = info.find('td', attrs={'data-stat' : 'pf'}).text
        result['PTS'] = info.find('td', attrs={'data-stat' : 'pts'}).text
        data.append(result)

    for info_ in tr_:
        result_ = {}
        result_['Rk'] = info_.find('th',attrs={'data-stat' : 'ranker'}).text
        result_['Player'] = info_.find('td', class_ = 'left').text
        result_['Pos'] = info_.find('td', class_ = 'center').text    
        result_['Age'] = info_.find('td',class_='right').text
        result_['Tm'] = info_.find('td', attrs={'data-stat' : 'team_id'}).text
        result_['G'] = info_.find('td', attrs={'data-stat' : 'g'}).text
        result_['MP'] = info_.find('td', attrs={'data-stat' : 'mp'}).text
        result_['PER'] = info_.find('td', attrs={'data-stat' : 'per'}).text 
        result_['TS%'] = info_.find('td', attrs={'data-stat' : 'ts_pct'}).text
        result_['3PAr'] = info_.find('td', attrs={'data-stat' : 'fg3a_per_fga_pct'}).text
        result_['FTr'] = info_.find('td', attrs={'data-stat' : 'fta_per_fga_pct'}).text
        result_['ORB%'] = info_.find('td', attrs={'data-stat' : 'orb_pct'}).text
        result_['DRB%'] = info_.find('td', attrs={'data-stat' : 'drb_pct'}).text
        result_['TRB%'] = info_.find('td', attrs={'data-stat' : 'trb_pct'}).text
 
        result_['AST%'] = info_.find('td', attrs={'data-stat' : 'ast_pct'}).text

        result['STL%'] = info_.find('td', attrs={'data-stat' : 'stl_pct'}).text

        result_['BLK%'] = info_.find('td', attrs={'data-stat' : 'blk_pct'}).text

        result_['TOV%'] = info_.find('td', attrs={'data-stat' : 'tov_pct'}).text
  
        result_['USG%'] = info_.find('td', attrs={'data-stat' : 'usg_pct'}).text
     
        result_['OWS'] = info_.find('td', attrs={'data-stat' : 'ows'}).text
        result_['DWS'] = info_.find('td', attrs={'data-stat' : 'dws'}).text
        result_['WS'] = info_.find('td', attrs={'data-stat' : 'ws'}).text   
        result_['WS/48'] = info_.find('td', attrs={'data-stat' : 'ws_per_48'}).text
        result_['OBPM'] = info_.find('td', attrs={'data-stat' : 'obpm'}).text
        result_['DBPM'] = info_.find('td', attrs={'data-stat' : 'dbpm'}).text
        result_['BPM'] = info_.find('td', attrs={'data-stat' : 'bpm'}).text
        result_['VORP'] = info_.find('td', attrs={'data-stat' : 'vorp'}).text
        data_.append(result_)
    
total =  pd.DataFrame(data)
advanced =  pd.DataFrame(data_)
print(total)
print('============')
print(advanced)
    #total_advanced = pd.merge(total,advanced,how='outer', on =['Rk','Player','Pos','Age','Tm','G','MP'])
#total_advanced.to_csv('test.csv')
#total_advanced

    
    




#df.to_csv('test.csv')
# Out:
#       2P   2P%   2PA 3P 3P% 3PA  AST Age BLK DRB  ...    PTS  \
# 0    548  .448  1222             170  23          ...   1674
# 1     48  .298   161              70  31          ...    126
# 2    272  .338   804             137  28          ...    781
# 3    349  .389   897             255  27          ...    820
# 4      6  .273    22               4  22          ...     16
# 5      6  .194    31               9  30          ...     17
# 6    110  .359   306             168  27          ...    319
# 7    202  .387   522              90  24          ...    500
# 8    200  .299   668             177  26          ...    656
# 9    149  .369   404              76  26          ...    405
# 10   342  .352   972             233  28          ...   1051
# 11    22  .349    63               9  22          ...     54
# 12    97  .404   240              91  26          ...    254
# 13    42  .269   156              27  27          ...    110
# 14   109  .344   317              83  26          ...    291
# 15   129  .315   409             117  24          ...    383
# 16    99  .354   280             148  34          ...    417
# 17    29  .302    96              34  24          ...     88
# 18   244  .335   729             209  29          ...    658
# 19   120  .308   389              76  30          ...    347
# 20   308  .415   742             208  27          ...    736
# 21   197  .361   545             134  25          ...    543
# 22   512  .369  1388             441  23          ...   1433
# 23    98  .351   279              57  27          ...    293
# 24    14  .368    38               5  26          ...     35
# 25   379  .383   990             390  32          ...   1052
# 26    20  .476    42              14  26          ...     64
# 27    40  .294   136              50  25          ...    127
# 28   201  .487   413             228  25          ...    551
# 29   270  .332   813             135  29          ...    743
# ..   ...   ...   ... ..  ..  ..  ...  ..  ..  ..  ...    ...
# 86   165  .349   473              90  29          ...    493
# 87    99  .347   285              50  25          ...    261
# 88     4  .222    18               1  22          ...     11
# 89   365  .394   926             150  27          ...   1032
# 90   300  .401   749             128  28          ...    854
# 91   157  .360   436             147  27          ...    433
# 92     9  .209    43              12  23          ...     36
# 93   281  .361   778             247  26          ...    872
# 94   263  .355   740             182  23          ...    868
# 95    19  .292    65               6  23          ...     47
# 96    89  .283   315             102  29          ...    268
# 97   290  .334   867             303  29          ...    933
# 98   164  .361   454             280  29          ...    474
# 99   206  .335   615             220  24          ...    598
# 100   76  .322   236              66  24          ...    248
# 101  244  .389   628             151  25          ...    671
# 102  227  .378   600             121  26          ...    629
# 103    1  .250     4               0  23          ...      2
# 104  102  .345   296              60  25          ...    234
# 105   53  .321   165              25  23          ...    147
# 106   13  .206    63               8  33          ...     40
# 107  225  .395   570             163  27          ...    566
# 108  213  .327   651             222  25          ...    608
# 109    7  .269    26               9  28          ...     23
# 110  200  .438   457             164  23          ...    524
# 111   89  .410   217              40  30          ...    204
# 112  220  .401   549             137  24          ...    671
# 113  328  .425   772             262  30          ...   1033
# 114   79  .299   264             108  25          ...    236
# 115  322  .336   958             156  26          ...    931
#
#                Player  Pos   Rk STL STL% TOV  TRB   Tm  eFG%
# 0        Paul Arizin*   SF    1      NaN      745  PHW  .448
# 1        Cliff Barker   SG    2      NaN       81  INO  .298
# 2      Don Barksdale*   PF    3      NaN      601  BLB  .338
# 3       Leo Barnhorst   SF    4      NaN      430  INO  .389
# 4        Elmer Behnke    C    5      NaN       17  MLH  .273
# 5       Charlie Black  F-C    6      NaN       31  MLH  .194
# 6         Nelson Bobb   PG    7      NaN      147  PHW  .359
# 7        Vince Boryla   SF    8      NaN      219  NYK  .387
# 8           Don Boven   SG    9      NaN      336  MLH  .299
# 9         Bob Brannum   PF   10      NaN      406  BOS  .369
# 10      Frankie Brian   SG   11      NaN      232  FTW  .352
# 11         Stan Brown    F   12      NaN       17  PHW  .349
# 12         Walt Budko   PF   13      NaN      232  PHW  .404
# 13         Art Burris   SF   14      NaN       99  TOT  .269
# 14    Gerry Calabrese   SG   15      NaN       84  SYR  .344
# 15       Bill Calhoun   SG   16      NaN      252  BLB  .315
# 16          Al Cervi*   PG   17      NaN       87  SYR  .354
# 17    Cal Christensen   SF   18      NaN       82  MLH  .302
# 18       Nat Clifton*   PF   19      NaN      731  NYK  .335
# 19         Bill Closs   SF   20      NaN      204  FTW  .308
# 20       Jack Coleman   PF   21      NaN      692  ROC  .415
# 21       Chuck Cooper   SF   22      NaN      502  BOS  .361
# 22         Bob Cousy*   PG   23      NaN      421  BOS  .369
# 23    Dillard Crocker   PF   24      NaN      111  TOT  .351
# 24          Ed Dahler    F   25      NaN       22  PHW  .368
# 25        Bob Davies*   PG   26      NaN      189  ROC  .383
# 26        Nate DeLong    C   27      NaN       31  MLH  .476
# 27        Dick Dickey   PG   28      NaN       81  BOS  .294
# 28         Bob Donham   SG   29      NaN      330  BOS  .487
# 29      Dike Eddleman   SF   30      NaN      269  TOT  .332
# ..                ...  ...  ...  ..  ...  ..  ...  ...   ...
# 86   George Ratkovicz   PF   87      NaN      328  SYR  .349
# 87       Don Rehfeldt   SF   88      NaN      243  TOT  .347
# 88      John Rennicke    G   89      NaN        9  MLH  .222
# 89       Arnie Risen*    C   90      NaN      841  ROC  .394
# 90          Red Rocha    C   91      NaN      549  SYR  .401
# 91           Pep Saul  G-F   92      NaN      165  TOT  .360
# 92         Don Savage  F-G   93      NaN       24  SYR  .209
# 93        Fred Schaus   SF   94      NaN      434  FTW  .361
# 94     Dolph Schayes*   PF   95      NaN      773  SYR  .355
# 95       Herb Scherer    C   96      NaN       26  NYK  .292
# 96      Howie Schultz   PF   97      NaN      246  MNL  .283
# 97       Fred Scolari   PG   98      NaN      214  BLB  .334
# 98     George Senesky   PG   99      NaN      232  PHW  .361
# 99       Paul Seymour   SG  100      NaN      225  SYR  .335
# 100       Chuck Share    C  101      NaN      331  FTW  .322
# 101     Bill Sharman*   SG  102      NaN      221  BOS  .389
# 102    Connie Simmons    C  103      NaN      471  NYK  .378
# 103     Zeke Sinicola    G  104      NaN        1  FTW  .250
# 104      Whitey Skoog   SG  105      NaN      122  MNL  .345
# 105     Jim Slaughter    C  106      NaN      148  BLB  .321
# 106     Belus Smawley   SG  107      NaN       18  BLB  .206
# 107       Odie Spears   SF  108      NaN      303  ROC  .395
# 108      Bill Tosheff   PG  109      NaN      216  INO  .327
# 109        Gene Vance  G-F  110      NaN       15  MLH  .269
# 110  Ernie Vandeweghe   SF  111      NaN      264  NYK  .438
# 111      Brady Walker   PF  112      NaN      195  BLB  .410
# 112      Paul Walther   SG  113      NaN      246  INO  .401
# 113     Bobby Wanzer*   SG  114      NaN      333  ROC  .425
# 114        Bob Wilson   PG  115      NaN      210  MLH  .299
# 115     Max Zaslofsky   SG  116               194  NYK  .336
#
# [116 rows x 31 columns]
# ============
#     3PAr AST% Age BLK% BPM DBPM DRB%  DWS   FTr   G   ...    Pos   Rk TOV%  \
# 0              23                     1.2  .579  66   ...     SF    1
# 1              31                     0.8  .317  44   ...     SG    2
# 2              28                     1.4  .427  62   ...     PF    3
# 3              27                     3.5  .208  66   ...     SF    4
# 4              22                     0.1  .318   4   ...      C    5
# 5              30                     0.1  .387  13   ...    F-C    6
# 6              27                     0.4  .546  62   ...     PG    7
# 7              24                     0.9  .220  42   ...     SF    8
# 8              26                     1.7  .524  66   ...     SG    9
# 9              26                     1.5  .423  66   ...     PF   10
# 10             28                     1.8  .445  66   ...     SG   11
# 11             22                     0.0  .286  15   ...      F   12
# 12             26                     0.4  .371  63   ...     PF   13
# 13             27                     0.4  .250  41   ...     SF   14
# 14             26                     0.9  .325  58   ...     SG   15
# 15             24                     0.8  .447  55   ...     SG   16
# 16             34                     1.2  .886  55   ...     PG   17
# 17             24                     0.4  .594  24   ...     SF   18
# 18             29                     2.3  .351  62   ...     PF   19
# 19             30                     0.9  .404  57   ...     SF   20
# 20             27                     2.3  .228  66   ...     PF   21
# 21             25                     2.1  .369  66   ...     SF   22
# 22             23                     2.8  .365  66   ...     PG   23
# 23             27                     0.6  .520  38   ...     PF   24
# 24             26                     0.0  .184  14   ...      F   25
# 25             32                     1.6  .383  65   ...     PG   26
# 26             26                     0.1  .833  17   ...      C   27
# 27             25                     0.4  .507  45   ...     PG   28
# 28             25                     1.9  .709  66   ...     SG   29
# 29             29                     1.4  .408  66   ...     SF   30
# ..   ...  ...  ..  ...  ..  ...  ...  ...   ...  ..   ...    ...  ...  ...
# 86             29                     1.9  .512  66   ...     PF   87
# 87             25                     0.8  .281  39   ...     SF   88
# 88             22                     0.0  .500   6   ...      G   89
# 89             27                     2.5  .465  66   ...      C   90
# 90             28                     3.2  .441  66   ...      C   91
# 91             27                          .351  64   ...    G-F   92
# 92             23                     0.2  .651  12   ...    F-G   93
# 93             26                     2.3  .478  62   ...     SF   94
# 94             23                     4.0  .573  63   ...     PF   95
# 95             23                     0.1  .215  12   ...      C   96
# 96             29                     2.9  .378  66   ...     PF   97
# 97             29                     1.1  .488  64   ...     PG   98
# 98             29                     0.7  .427  57   ...     PG   99
# 99             24                     2.4  .398  66   ...     SG  100
# 100            24                     1.2  .657  63   ...      C  101
# 101            25                     1.3  .339  63   ...     SG  102
# 102            26                     1.5  .423  66   ...      C  103
# 103            23                     0.0  .500   3   ...      G  104
# 104            25                     1.7  .128  35   ...     SG  105
# 105            23                     0.3  .412  28   ...      C  106
# 106            33                     0.1  .270  11   ...     SG  107
# 107            27                     1.2  .267  66   ...     SF  108
# 108            25                     2.4  .339  65   ...     PG  109
# 109            28                     0.1  .538   7   ...    G-F  110
# 110            23                     1.2  .350  57   ...     SF  111
# 111            30                     0.4  .157  35   ...     PF  112
# 112            24                     2.1  .561  55   ...     SG  113
# 113            30                     1.6  .540  66   ...     SG  114
# 114            25                     1.0  .511  63   ...     PG  115
# 115            26                     1.1  .397  66   ...     SG  116
#
#     TRB%   TS%   Tm USG% VORP    WS   WS/48
# 0         .546  PHW            16.0    .261
# 1         .343  INO             0.1    .008
# 2         .409  BLB             1.5    .036
# 3         .419  INO             4.7    .097
# 4         .319  MLH            -0.1  -0.098
# 5         .234  MLH            -0.4  -0.148
# 6         .420  PHW             1.2    .048
# 7         .437  NYK             2.1    .069
# 8         .399  MLH             1.5    .036
# 9         .423  BOS             2.0    .074
# 10        .452  FTW             6.1    .110
# 11        .381  PHW            -0.1  -0.035
# 12        .455  PHW             1.5    .065
# 13        .318  TOT            -0.8  -0.073
# 14        .402  SYR             0.9    .046
# 15        .391  BLB             0.4    .012
# 16        .536  SYR             5.3    .297
# 17        .363  MLH             0.0    .002
# 18        .391  NYK             1.6    .036
# 19        .379  FTW             0.0  -0.001
# 20        .451  ROC             5.0    .093
# 21        .429  BOS             3.1    .076
# 22        .445  BOS             7.7    .138
# 23        .427  TOT             1.2    .072
# 24        .426  PHW             0.1    .036
# 25        .455  ROC             6.3    .126
# 26        .557  MLH             0.8    .309
# 27        .382  BOS             0.3    .028
# 28        .508  BOS             6.1    .149
# 29        .387  TOT            -0.1  -0.003
# ..   ...   ...  ...  ...  ...   ...     ...
# 86        .425  SYR             2.8    .098
# 87        .408  TOT             0.8    .048
# 88        .250  MLH            -0.2  -0.218
# 89        .463  ROC             6.8    .137
# 90        .478  SYR             7.8    .148
# 91        .430  TOT
# 92        .325  SYR            -0.1  -0.053
# 93        .463  FTW             6.8    .127
# 94        .468  SYR             8.5    .203
# 95        .330  NYK            -0.3  -0.092
# 96        .365  MNL             2.0    .074
# 97        .443  BLB             4.5    .096
# 98        .439  PHW             2.6    .066
# 99        .414  SYR             3.2    .069
# 100       .408  FTW             1.3    .070
# 101       .465  BOS             4.3    .148
# 102       .442  NYK             3.3    .102
# 103       .205  FTW            -0.1  -0.236
# 104       .374  MNL             1.0    .048
# 105       .377  BLB            -0.1  -0.010
# 106       .284  BLB            -0.6  -0.195
# 107       .444  ROC             3.1    .090
# 108       .406  INO             2.9    .068
# 109       .358  MLH             0.0  -0.008
# 110       .497  NYK             4.8    .154
# 111       .440  BLB             1.0    .066
# 112       .490  INO             6.6    .167
# 113       .541  ROC            11.4    .218
# 114       .365  MLH             0.2    .008
# 115       .414  NYK             1.7    .038
#
# [116 rows x 26 columns]

# %%
total_advanced = pd.merge(total,advanced,how='outer', on =['Rk','Player','Pos','Age','Tm','G','MP'])
total_advanced.to_csv('test.csv')
