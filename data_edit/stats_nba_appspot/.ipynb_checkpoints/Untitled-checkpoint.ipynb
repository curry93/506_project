# %%
import pandas as pd 
from bs4 import BeautifulSoup
import urllib
from collections import OrderedDict

def select_calss(css_class):
    if css_class == 'oddrow' or css_class =='evenrow':
        return css_class

data = []   
page = 'http://www.espn.com/nba/statistics/rpm/_/year/2014/sort/RPM'
r = urllib.request.urlopen(page)
soup = BeautifulSoup(r,'lxml')
page_num = 1
while(page_num != 12 ):   
    tr = soup.find_all(class_ = select_calss)
    for info in tr:
        tmp = []
        for td in info:
            #print(td.text)
            tmp.append(td.text)
        result = OrderedDict()
        result['Name'] = tmp[1]
        result['Team'] = tmp[2]
        result['GP'] = tmp[3]
        result['MPG'] = tmp[4]
        result['ORPM'] = tmp[5]
        result['DRPM'] = tmp[6]
        result['RPM'] = tmp[7]
        result['WINS'] = tmp[8]        
        data.append(result)
    try:
        page = 'http://www.espn.com/nba/statistics/rpm/_/year/2014/page/'+str(page_num)+'/sort/RPM'
        print('next_page:',page)
        r = urllib.request.urlopen(page)
        soup = BeautifulSoup(r,'lxml')
        page_num += 1 
    except:
        page_num = 12
rpm = pd.DataFrame(data)
rpm.to_csv('RPM.csv')
# Out:
# next_page: http://www.espn.com/nba/statistics/rpm/_/year/2014/page/1/sort/RPM
# next_page: http://www.espn.com/nba/statistics/rpm/_/year/2014/page/2/sort/RPM
# next_page: http://www.espn.com/nba/statistics/rpm/_/year/2014/page/3/sort/RPM
# next_page: http://www.espn.com/nba/statistics/rpm/_/year/2014/page/4/sort/RPM
# next_page: http://www.espn.com/nba/statistics/rpm/_/year/2014/page/5/sort/RPM
# next_page: http://www.espn.com/nba/statistics/rpm/_/year/2014/page/6/sort/RPM
# next_page: http://www.espn.com/nba/statistics/rpm/_/year/2014/page/7/sort/RPM
# next_page: http://www.espn.com/nba/statistics/rpm/_/year/2014/page/8/sort/RPM
# next_page: http://www.espn.com/nba/statistics/rpm/_/year/2014/page/9/sort/RPM
# next_page: http://www.espn.com/nba/statistics/rpm/_/year/2014/page/10/sort/RPM
# next_page: http://www.espn.com/nba/statistics/rpm/_/year/2014/page/11/sort/RPM
#                       Name     Team  GP   MPG   ORPM   DRPM    RPM   WINS
# 0         LeBron James, SF      MIA  77  37.7   8.65   0.43   9.08  19.87
# 1           Chris Paul, PG      LAC  62  35.0   6.03   1.95   7.98  14.47
# 2       Andre Iguodala, SF       GS  63  32.4   1.89   4.74   6.63  11.47
# 3         Kevin Durant, SF      OKC  81  38.5   6.27   0.15   6.42  17.63
# 4        Dirk Nowitzki, PF      DAL  80  32.9   4.56   1.79   6.35  14.05
# 5        Stephen Curry, PG       GS  78  36.5   6.62  -0.38   6.24  15.48
# 6        Nick Collison, PF      OKC  81  16.7   2.08   3.64   5.72   6.90
# 7        Manu Ginobili, SG       SA  68  22.8   5.07   0.35   5.42   7.68
# 8            Tim Duncan, C       SA  74  29.2  -0.05   5.38   5.33  10.39
# 9    LaMarcus Aldridge, PF      POR  69  36.2   1.89   3.23   5.12  11.64
# 10       Channing Frye, PF      PHX  82  28.2   3.92   1.17   5.09  10.83
# 11          Kevin Love, PF      MIN  77  36.3   3.52   1.54   5.06  13.52
# 12   Russell Westbrook, PG      OKC  46  30.7   4.82   0.23   5.05   6.89
# 13         Mike Conley, PG      MEM  73  33.5   4.28   0.42   4.70  10.24
# 14       Blake Griffin, PF      LAC  80  35.8   2.65   2.00   4.65  12.79
# 15        Amir Johnson, PF      TOR  77  28.8   1.47   3.14   4.61   9.22
# 16          Joakim Noah, C      CHI  80  35.3   0.65   3.92   4.57  11.30
# 17        Vince Carter, SG      DAL  81  24.4   2.02   2.46   4.48   8.35
# 18         Serge Ibaka, PF      OKC  81  32.9   1.23   3.23   4.46  11.63
# 19    Patrick Beverley, PG      HOU  56  31.3   2.98   1.29   4.27   7.27
# 20          Kyle Lowry, PG      TOR  79  36.2   3.84   0.41   4.25  11.56
# 21        Dwight Howard, C      HOU  71  33.7  -0.67   4.91   4.24   9.86
# 22          Taj Gibson, PF      CHI  82  28.7   0.56   3.64   4.20   8.84
# 23        Marcin Gortat, C      WSH  81  32.8   0.12   4.00   4.12  10.37
# 24        Eric Bledsoe, PG      PHX  43  32.9   0.11   3.97   4.08   5.79
# 25     Anderson Varejao, C      CLE  65  27.7   0.47   3.59   4.06   6.88
# 26      Chris Andersen, PF      MIA  72  19.4   0.19   3.81   4.00   5.17
# 27         Patty Mills, PG       SA  81  18.9   3.42   0.58   4.00   6.07
# 28         Ricky Rubio, PG      MIN  82  32.2   1.43   2.47   3.90  10.76
# 29       Kevin Garnett, PF      BKN  54  20.5  -2.78   6.60   3.82   4.02
# ..                     ...      ...  ..   ...    ...    ...    ...    ...
# 410        Cory Joseph, PG       SA  68  13.8  -0.74  -2.94  -3.68  -0.78
# 411    Hollis Thompson, SF      PHI  77  22.6  -0.22  -3.46  -3.68  -1.50
# 412      Brian Roberts, PG       NO  72  23.2  -1.45  -2.33  -3.78  -1.45
# 413   Andrew Nicholson, PF      ORL  76  15.4  -4.79   1.00  -3.79  -1.03
# 414      Udonis Haslem, PF      MIA  46  14.2  -4.81   1.01  -3.80  -0.55
# 415      Vitor Faverani, C      BOS  37  13.2  -4.32   0.50  -3.82  -0.44
# 416      D.J. Augustin, PG  CHI/TOR  71  27.3   0.03  -3.88  -3.85  -1.70
# 417          Aaron Gray, C  SAC/TOR  37   9.6  -4.35   0.46  -3.89  -0.33
# 418    Thomas Robinson, PF      POR  70  12.5  -2.34  -1.55  -3.89  -0.82
# 419         Doron Lamb, SG      ORL  53  13.1  -1.61  -2.29  -3.90  -0.65
# 420        Peyton Siva, PG      DET  24   9.3  -1.41  -2.53  -3.94  -0.21
# 421      Jannero Pargo, PG      CHA  29   8.3  -1.13  -2.84  -3.97  -0.24
# 422   Brandon Jennings, PG      DET  80  34.1   0.39  -4.37  -3.98  -2.82
# 423     Bismack Biyombo, C      CHA  77  13.9  -3.90  -0.11  -4.01  -1.06
# 424       Luke Ridnour, PG  MIL/CHA  61  18.7  -1.26  -2.76  -4.02  -1.13
# 425     Diante Garrett, PG     UTAH  71  14.8  -2.71  -1.41  -4.12  -1.12
# 426      Carlos Boozer, PF      CHI  76  28.2  -4.11  -0.02  -4.13  -2.28
# 427     John Lucas III, PG     UTAH  42  14.1  -2.38  -1.75  -4.13  -0.64
# 428    Erik Jay Murphy, PF      CHI  24   2.6  -3.47  -0.66  -4.13  -0.07
# 429    Arnett Moultrie, PF      PHI  12  15.6  -1.94  -2.21  -4.15  -0.23
# 430      E'Twaun Moore, SG      ORL  79  19.1  -2.99  -1.21  -4.20  -1.71
# 431      Rasual Butler, SF      IND  50   7.6  -2.30  -1.93  -4.23  -0.43
# 432           Greg Oden, C      MIA  23   9.2  -3.60  -0.66  -4.26  -0.25
# 433          Gal Mekel, PG      DAL  31   9.4  -1.67  -2.60  -4.27  -0.36
# 434         Jan Vesely, PF  DEN/WSH  54  14.4  -4.44   0.14  -4.30  -0.95
# 435    Kendrick Perkins, C      OKC  62  19.5  -7.25   2.94  -4.31  -1.51
# 436      Isaiah Canaan, PG      HOU  22  11.5  -1.25  -3.06  -4.31  -0.33
# 437     Wesley Johnson, SF      LAL  79  28.4  -3.54  -0.83  -4.37  -3.01
# 438       Mike Muscala, PF      ATL  20  10.8  -3.20  -1.18  -4.38  -0.28
# 439     Jeffery Taylor, SF      CHA  26  24.2  -3.58  -0.82  -4.40  -0.80
#
# [440 rows x 8 columns]

# %%
# Out:
# '//www.espn.com/nba/statistics/rpm/_/year/2014/page/2/sort/RPM'
